# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata
import passwords
from passwords import *

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.ny.gov", API_TOKEN)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.ny.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("wujg-7c2s", limit=10000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#             transit_timestamp transit_mode station_complex_id  \
# 0     2024-08-30T11:00:00.000       subway                217
# 1     2024-08-30T18:00:00.000       subway                245
# 2     2024-08-30T04:00:00.000       subway                 82
# 3     2024-08-30T15:00:00.000       subway                459
# 4     2024-08-30T00:00:00.000       subway                119
# ...                       ...          ...                ...
# 9995  2024-08-30T00:00:00.000       subway                355
# 9996  2024-08-30T14:00:00.000       subway                195
# 9997  2024-08-30T23:00:00.000       subway                243
# 9998  2024-08-30T22:00:00.000       subway                210
# 9999  2024-08-30T09:00:00.000       subway                626
#
#                                station_complex    borough payment_method  \
# 0                                 170 St (B,D)      Bronx      metrocard
# 1                                    18 Av (F)   Brooklyn      metrocard
# 2                                 104 St (J,Z)     Queens      metrocard
# 3                          40 St-Lowery St (7)     Queens      metrocard
# 4                                     1 Av (L)  Manhattan      metrocard
# ...                                        ...        ...            ...
# 9995                         Winthrop St (2,5)   Brooklyn      metrocard
# 9996              Ozone Park-Lefferts Blvd (A)     Queens           omny
# 9997                           Church Av (F,G)   Brooklyn      metrocard
# 9998                        Norwood-205 St (D)      Bronx      metrocard
# 9999  Franklin Av (2,3,4,5)/Botanic Garden (S)   Brooklyn      metrocard
#
#                    fare_class_category ridership transfers   latitude  \
# 0     Metrocard - Seniors & Disability       6.0       1.0  40.839306
# 1          Metrocard - Unlimited 7-Day      13.0       0.0  40.629753
# 2                    Metrocard - Other       4.0       0.0   40.69518
# 3                Metrocard - Fair Fare      15.0       0.0  40.743782
# 4          Metrocard - Unlimited 7-Day      16.0       0.0  40.730953
# ...                                ...       ...       ...        ...
# 9995             Metrocard - Full Fare       2.0       0.0   40.65665
# 9996                  OMNY - Full Fare      43.0       0.0   40.68595
# 9997       Metrocard - Unlimited 7-Day       4.0       0.0   40.64404
# 9998             Metrocard - Full Fare       6.0       0.0   40.87481
# 9999  Metrocard - Seniors & Disability      30.0       0.0   40.67068
#
#        longitude                                       georeference  \
# 0       -73.9134  {'type': 'Point', 'coordinates': [-73.9134, 40...
# 1     -73.976974  {'type': 'Point', 'coordinates': [-73.976974, ...
# 2      -73.84433  {'type': 'Point', 'coordinates': [-73.84433, 4...
# 3      -73.92402  {'type': 'Point', 'coordinates': [-73.92402, 4...
# 4      -73.98163  {'type': 'Point', 'coordinates': [-73.98163, 4...
# ...          ...                                                ...
# 9995    -73.9502  {'type': 'Point', 'coordinates': [-73.9502, 40...
# 9996    -73.8258  {'type': 'Point', 'coordinates': [-73.8258, 40...
# 9997  -73.979675  {'type': 'Point', 'coordinates': [-73.979675, ...
# 9998   -73.87885  {'type': 'Point', 'coordinates': [-73.87885, 4...
# 9999   -73.95813  {'type': 'Point', 'coordinates': [-73.95813, 4...
#
#      :@computed_region_kjdx_g34t :@computed_region_yamh_8v7k  \
# 0                           2032                         307
# 1                           2090                         894
# 2                           2137                         196
# 3                           2137                         196
# 4                           2095                         749
# ...                          ...                         ...
# 9995                        2090                         894
# 9996                        2137                         196
# 9997                        2090                         894
# 9998                        2032                         307
# 9999                        2090                         894
#
#      :@computed_region_wbg7_3whc
# 0                            652
# 1                            813
# 2                           1165
# 3                            876
# 4                            724
# ...                          ...
# 9995                         809
# 9996                        1166
# 9997                         896
# 9998                         704
# 9999                         809
#
# [10000 rows x 15 columns]

# %%
results_df["station_complex"]
# Out:
# 0                                   170 St (B,D)
# 1                                      18 Av (F)
# 2                                   104 St (J,Z)
# 3                            40 St-Lowery St (7)
# 4                                       1 Av (L)
#                           ...
# 9995                           Winthrop St (2,5)
# 9996                Ozone Park-Lefferts Blvd (A)
# 9997                             Church Av (F,G)
# 9998                          Norwood-205 St (D)
# 9999    Franklin Av (2,3,4,5)/Botanic Garden (S)
# Name: station_complex, Length: 10000, dtype: object

# %%
filtered_df = results_df[results_df['station_complex'] == 'Bedford Park Blvd-Lehman College (4)']

# Select the required columns
selected_columns = ['transit_mode', 'station_complex', 'payment_method', 'fare_class_category']
filtered_df = filtered_df[selected_columns]

# Display the filtered table
filtered_df
# Out:
#      transit_mode                       station_complex payment_method  \
# 32         subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 368        subway  Bedford Park Blvd-Lehman College (4)           omny
# 635        subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 710        subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 1824       subway  Bedford Park Blvd-Lehman College (4)           omny
# 1955       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 2145       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 2360       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 2584       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 3138       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 3169       subway  Bedford Park Blvd-Lehman College (4)           omny
# 3181       subway  Bedford Park Blvd-Lehman College (4)           omny
# 3746       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 3938       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 4886       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 5204       subway  Bedford Park Blvd-Lehman College (4)           omny
# 6236       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 7728       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 8329       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 8575       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 8616       subway  Bedford Park Blvd-Lehman College (4)      metrocard
# 8674       subway  Bedford Park Blvd-Lehman College (4)           omny
# 8681       subway  Bedford Park Blvd-Lehman College (4)           omny
# 8891       subway  Bedford Park Blvd-Lehman College (4)      metrocard
#
#                    fare_class_category
# 32    Metrocard - Seniors & Disability
# 368                       OMNY - Other
# 635              Metrocard - Full Fare
# 710        Metrocard - Unlimited 7-Day
# 1824                  OMNY - Full Fare
# 1955             Metrocard - Full Fare
# 2145             Metrocard - Fair Fare
# 2360  Metrocard - Seniors & Disability
# 2584              Metrocard - Students
# 3138  Metrocard - Seniors & Disability
# 3169                      OMNY - Other
# 3181                  OMNY - Full Fare
# 3746       Metrocard - Unlimited 7-Day
# 3938             Metrocard - Fair Fare
# 4886             Metrocard - Fair Fare
# 5204                  OMNY - Full Fare
# 6236                 Metrocard - Other
# 7728  Metrocard - Seniors & Disability
# 8329      Metrocard - Unlimited 30-Day
# 8575              Metrocard - Students
# 8616              Metrocard - Students
# 8674                  OMNY - Full Fare
# 8681                  OMNY - Full Fare
# 8891              Metrocard - Students
